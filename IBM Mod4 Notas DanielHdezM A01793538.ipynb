# %% [markdown]
# # Daniel Hernandez Mora Matricula A01793538
# # Ejercicios Modulo 4 Curso IBM

# %% [markdown]
# # Laboratorio Reading Files Mod 4

# %% [markdown]
# # Importando archivo

# %% [markdown]
# # Progreso
#
# > ![image.png](attachment:image.png)

# %%
import urllib.request
url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/example1.txt'
filename = 'Example1.txt'
urllib.request.urlretrieve(url, filename)
# Out:
# ('Example1.txt', <http.client.HTTPMessage at 0x1e7c94c9610>)

# %% [markdown]
# # Primera opcion para abrir un archivo de Texto

# %%
# Read the Example1.txt
example1 = "Example1.txt"
file1 = open(example1, "r")

# %%
# Print the path of file
file1.name
# Out:
# 'Example1.txt'

# %%
# Print the mode of file, either 'r' or 'w'
file1.mode
# Out:
# 'r'

# %%
# Read the file
FileContent = file1.read()
FileContent
# Out:
# 'This is line 1 \nThis is line 2\nThis is line 3'

# %%
# Print the file with '\n' as a new line
print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3

# %%
type(FileContent)
# Out:
# str

# %% [markdown]
# Recomendacion de cerrar el archivo

# %%
# Close file after finish
file1.close()

# %% [markdown]
# # Segunda Opcion para abrir archivos, (una mejor forma)

# %%
# Open file using with
with open(example1, "r") as file1:
    FileContent = file1.read()
    print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3

# %%
# Verify if the file is closed
file1.closed
# Out:
# True

# %%
# See the content of file
print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3

# %% [markdown]
# #Podemos tambien ver el contenido a partir de la cantidad de caracteres del archivo

# %%
# Read first four characters
with open(example1, "r") as file1:
    print(file1.read(4))
# Out:
# This

# %% [markdown]
# #Aqui se leen los primeros 4,  luego los otros 4 y posteriormente 7 y 15 caracteres de todo el archivo

# %%
# Read certain amount of characters
with open(example1, "r") as file1:
    print(file1.read(4))
    print(file1.read(4))
    print(file1.read(7))
    print(file1.read(15))
# Out:
# This
#  is
# line 1
#
# This is line 2

# %% [markdown]
# #Aqui primero se leen 16 y luego 5 y 9 caracteres por eso se despliega difernete

# %%
# Read certain amount of characters
with open(example1, "r") as file1:
    print(file1.read(16))
    print(file1.read(5))
    print(file1.read(9))
# Out:
# This is line 1
#
# This
# is line 2

# %% [markdown]
# #argumento readline para ver una linea entera

# %%
# Read one line
with open(example1, "r") as file1:
    print("first line: " + file1.readline())
# Out:
# first line: This is line 1

# %% [markdown]
# #el argumento readline no puede leer mas alla de una línea, asi el argumento se exceda de los caracteres ( en este caso son 16) a diferencia del argumento que si se salta de linea

# %%
with open(example1, "r") as file1:
    print(file1.readline(20)) # does not read past the end of line
    print(file1.read(20)) # Returns the next 20 chars
# Out:
# This is line 1
#
# This is line 2
# This

# %% [markdown]
# #podemos utilizar la funcion loop para avanzar entre lineas

# %%
# Iterate through the lines
with open(example1,"r") as file1:
        i = 0;
        for line in file1:
            print("Iteration", str(i), ": ", line)
            i = i + 1
# Out:
# Iteration 0 :  This is line 1
#
# Iteration 1 :  This is line 2
#
# Iteration 2 :  This is line 3

# %% [markdown]
# #guardando el contenido del archivo en una lista

# %%
# Read all lines and save as a list
with open(example1, "r") as file1:
    FileasList = file1.readlines()

# %% [markdown]
# #mostramos los 3 miembros de la lista

# %%
print (FileasList[0])
print (FileasList[1])
print (FileasList[2])
# Out:
# This is line 1
#
# This is line 2
#
# This is line 3

# %% [markdown]
# # Fin de laboratorio Reading Files MOd 4 IBM

# %% [markdown]
# # Lab 2 Mod 4 Writing Saving Files

# %% [markdown]
# #Escribiendo en un archivo

# %%
# Write line to file
exmp2 = 'Example2.txt'
with open(exmp2, 'w') as writefile:
    writefile.write("This is line A")

# %% [markdown]
# #Notar que cuando escribes el arugumento es "w" y cuando lees es "r"

# %%
# Read file
with open(exmp2, 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# This is line A

# %%
# Write lines to file

with open(exmp2, 'w') as writefile:
    writefile.write("This is line A\n")
    writefile.write("This is line B\n")

# %%
# Check whether write to file
with open(exmp2, 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# This is line A
# This is line B

# %% [markdown]
# #Crear un archivo a partir de una lista

# %%
# Sample list of text
Lines = ["This is line A\n", "This is line B\n", "This is line C\n"]
Lines
# Out:
# ['This is line A\n', 'This is line B\n', 'This is line C\n']

# %%
# Write the strings in the list to text file
with open('Example2.txt', 'w') as writefile:
    for line in Lines:
        print(line)
        writefile.write(line)
# Out:
# This is line A
#
# This is line B
#
# This is line C

# %% [markdown]
# # Es importante notar que el argumento "w" sobreescribe todo los datos del archivo

# %%
with open('Example2.txt', 'w') as writefile:
    writefile.write("Overwrite\n")
with open('Example2.txt', 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# Overwrite

# %% [markdown]
# # Appending Files, el metodo para no escribir en los archivos sin sobreescribir todos los datos

# %%
# Write a new line to text file
with open('Example2.txt', 'a') as testwritefile:
    testwritefile.write("This is line C\n")
    testwritefile.write("This is line D\n")
    testwritefile.write("This is line E\n")

# %%
# Verify if the new line is in the text file
with open('Example2.txt', 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# Overwrite
# This is line C
# This is line D
# This is line E

# %% [markdown]
# #Modos de apertura adicional
# > r+ : Reading and writing. Cannot truncate the file.
#
# > w+ : Writing and reading. Truncates the file.
#
# > a+ : Appending and Reading. Creates a new file, if none exists.

# %%
with open('Example2.txt', 'a+') as testwritefile:
    testwritefile.write("This is line E\n")
    print(testwritefile.read())

# %%
with open('Example2.txt', 'a+') as testwritefile:
    print("Initial Location: {}".format(testwritefile.tell()))
    
    data = testwritefile.read()
    if (not data):  #empty strings return false in python
            print('Read nothing') 
    else: 
            print(testwritefile.read())
            
    testwritefile.seek(0,0) # move 0 bytes from beginning.
    
    print("\nNew Location : {}".format(testwritefile.tell()))
    data = testwritefile.read()
    if (not data): 
            print('Read nothing') 
    else: 
            print(data)
    
    print("Location after read: {}".format(testwritefile.tell()) )
# Out:
# Initial Location: 75
# Read nothing
#
# New Location : 0
# Overwrite
# This is line C
# This is line D
# This is line E
# This is line E
#
# Location after read: 75

# %% [markdown]
# #.tell() - returns the current position in bytes
#
# #.seek(offset,from) - changes the position by 'offset' bytes with respect to 'from'.
# #From can take the value of 0,1,2 corresponding to beginning, relative to current position and end

# %% [markdown]
# # Copiando Archivos

# %%
# Copy file to another
with open('Example2.txt','r') as readfile:
    with open('Example3.txt','w') as writefile:
          for line in readfile:
                writefile.write(line)

# %%
# Verify if the copy is successfully executed
with open('Example3.txt','r') as testwritefile:
    print(testwritefile.read())
# Out:
# Overwrite
# This is line C
# This is line D
# This is line E
# This is line E

# %% [markdown]
# # Ejercicio

# %% [markdown]
# #El club de fans de los Raptors de su universidad local mantiene un registro de sus miembros activos en un documento .txt. Todos los meses actualizan el archivo eliminando a los miembros que no están activos. Se le ha asignado la tarea de automatizar esto con sus habilidades de Python.
# Dado el archivo currentMem, elimine cada miembro con un 'no' en su columna Activo. Realice un seguimiento de cada uno de los miembros eliminados y agréguelos al archivo exMem. Asegúrese de que se conserve el formato de los archivos originales. (Sugerencia: haga esto leyendo/escribiendo líneas completas y asegurándose de que el encabezado permanezca)

# %% [markdown]
# #El siguiente condigo sirve como base del ejercicio

# %%
from random import randint as rnd

memReg = 'members.txt'
exReg = 'inactive.txt'
fee =('yes','no')

def genFiles(current,old):
    with open(current,'w+') as writefile: 
        writefile.write('Membership No  Date Joined  Active  \n')
        data = "{:^13}  {:<11}  {:<6}\n"

        for rowno in range(20):
            date = str(rnd(2015,2020))+ '-' + str(rnd(1,12))+'-'+str(rnd(1,25))
            writefile.write(data.format(rnd(10000,99999),date,fee[rnd(0,1)]))


    with open(old,'w+') as writefile: 
        writefile.write('Membership No  Date Joined  Active  \n')
        data = "{:^13}  {:<11}  {:<6}\n"
        for rowno in range(3):
            date = str(rnd(2015,2020))+ '-' + str(rnd(1,12))+'-'+str(rnd(1,25))
            writefile.write(data.format(rnd(10000,99999),date,fee[1]))


genFiles(memReg,exReg)

# %% [markdown]
# #respuesta

# %%
   def cleanFiles(currentMem, exMem):
    with open(currentMem,'r+') as writeFile: 
        with open(exMem,'a+') as appendFile:
            #get the data
            writeFile.seek(0)
            members = writeFile.readlines()
            #remove header
            header = members[0]
            members.pop(0)
                
            inactive = [member for member in members if ('no' in member)]
            '''
            The above is the same as 

            for member in members:
            if 'no' in member:
                inactive.append(member)
            '''
            #go to the beginning of the write file
            writeFile.seek(0) 
            writeFile.write(header)
            for member in members:
                if (member in inactive):
                    appendFile.write(member)
                else:
                    writeFile.write(member)      
            writeFile.truncate()
                
memReg = 'members.txt'
exReg = 'inactive.txt'


# The code below is to help you view the files.
# Do not modify this code for this exercise.
memReg = 'members.txt'
exReg = 'inactive.txt'
cleanFiles(memReg,exReg)


headers = "Membership No  Date Joined  Active  \n"
with open(memReg,'r') as readFile:
    print("Active Members: \n\n")
    print(readFile.read())
    
with open(exReg,'r') as readFile:
    print("Inactive Members: \n\n")
    print(readFile.read())
# Out:
# Active Members:
#
#
# Membership No  Date Joined  Active
#     82385      2019-2-13    yes
#     77275      2019-7-11    yes
#     18341      2017-9-9     yes
#     98238      2016-2-25    yes
#     20358      2017-2-15    yes
#     31934      2020-7-11    yes
#     18497      2016-1-24    yes
#
# Inactive Members:
#
#
# Membership No  Date Joined  Active
#     62327      2016-6-4     no
#     73878      2020-5-25    no
#     96648      2015-4-14    no
#     92751      2018-10-10   no
#     85887      2016-6-2     no
#     56034      2015-2-18    no
#     95608      2019-5-5     no
#     67994      2017-5-3     no
#     78699      2016-1-17    no
#     39228      2017-7-4     no
#     60092      2020-11-5    no
#     24556      2020-7-2     no
#     49815      2016-1-3     no
#     66740      2016-11-8    no
#     45583      2019-2-25    no
#     68957      2019-9-25    no

# %% [markdown]
# # Trabajando con PANDAS

# %% [markdown]
# #Definamos un arreglo df para los ejercicios

# %%
import pandas as pd
df=pd.DataFrame({'a':[11,21,31],'b':[21,22,23]})

# %% [markdown]
# # Despleguemos los 3 primeros renglones de todas las columnas

# %%
df.head(3)
# Out:
#     a   b
# 0  11  21
# 1  21  22
# 2  31  23

# %% [markdown]
# #Ahora despleguemos solo la columna a

# %%
df["a"]
# Out:
# 0    11
# 1    21
# 2    31
# Name: a, dtype: int64

# %% [markdown]
# # Laboratorio para trabajar con PANDAS

# %% [markdown]
# # Primero obtenemos el archivo.csv del repositorio de IBM

# %%
import requests
URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/TopSellingAlbums.csv'
response = requests.get(URL)
open("TopSellingAlbums.csv", "wb").write(response.content)
# Out:
# 766

# %% [markdown]
# #Almacenamos en un objeto, en este caso df, los datos del arhivo TopSellingAlbums.csv

# %%
df = pd.read_csv("TopSellingAlbums.csv")

# %% [markdown]
# #Mostramos los 5 primeros renglones de la tabla

# %%
df.head()
# Out:
#             Artist                      Album  Released   Length  \
# 0  Michael Jackson                   Thriller      1982  0:42:19
# 1            AC/DC              Back in Black      1980  0:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston              The Bodyguard      1992  0:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  0:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65  30-Nov-82        NaN    10.0
# 1                        50  25-Jul-80        NaN     9.5
# ...

# %% [markdown]
# #Mostramos la columna "Length" y la asignamos a un nuevo DataFrame, en este caso, x

# %%
x = df[['Length']]
x
# Out:
#     Length
# 0  0:42:19
# 1  0:42:11
# 2  0:42:49
# 3  0:57:44
# 4  0:46:33
# 5  0:43:08
# 6  1:15:54
# 7  0:40:01

# %% [markdown]
# #Tambien se puede asignar a una serie, en vez de a otro dataframe

# %%
x=df["Length"]
x
# Out:
# 0    0:42:19
# 1    0:42:11
# 2    0:42:49
# 3    0:57:44
# 4    0:46:33
# 5    0:43:08
# 6    1:15:54
# 7    0:40:01
# Name: Length, dtype: object

# %% [markdown]
# #Con los siguientes argumentos, obtenemos mas de una comlumna y la asignamos a un nuevo dataframe llamado y

# %%
# Access to multiple columns
y = df[['Artist','Length','Genre']]
y
# Out:
#             Artist   Length                        Genre
# 0  Michael Jackson  0:42:19               pop, rock, R&B
# 1            AC/DC  0:42:11                    hard rock
# 2       Pink Floyd  0:42:49             progressive rock
# 3  Whitney Houston  0:57:44               R&B, soul, pop
# 4        Meat Loaf  0:46:33  hard rock, progressive rock
# 5           Eagles  0:43:08   rock, soft rock, folk rock
# 6         Bee Gees  1:15:54                        disco
# 7    Fleetwood Mac  0:40:01                    soft rock

# %% [markdown]
# #Existen diferntes argumentos para acceder especificamentes a los elementos dentro del dataframe

# %%
df.head()
# Out:
#             Artist                      Album  Released   Length  \
# 0  Michael Jackson                   Thriller      1982  0:42:19
# 1            AC/DC              Back in Black      1980  0:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston              The Bodyguard      1992  0:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  0:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65  30-Nov-82        NaN    10.0
# 1                        50  25-Jul-80        NaN     9.5
# ...

# %%
df.iloc[0, 0]
# Out:
# 'Michael Jackson'

# %%
df.iloc[1,0]
# Out:
# 'AC/DC'

# %%
df.iloc[0,2]
# Out:
# 1982

# %%
df.iloc[1,2]
# Out:
# 1980

# %%
df.loc[1, 'Artist']
# Out:
# 'AC/DC'

# %%
df.loc[1, 'Artist']
# Out:
# 'AC/DC'

# %%
df.loc[0, 'Released']
# Out:
# 1982

# %%
df.loc[1, 'Released']
# Out:
# 1980

# %% [markdown]
# # se puede extraer información del dataframe y armar otro dataframe a partir de este

# %%
df.head()
# Out:
#             Artist                      Album  Released   Length  \
# 0  Michael Jackson                   Thriller      1982  0:42:19
# 1            AC/DC              Back in Black      1980  0:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston              The Bodyguard      1992  0:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  0:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65  30-Nov-82        NaN    10.0
# 1                        50  25-Jul-80        NaN     9.5
# ...

# %%
df.iloc[0:2, 0:3]
# Out:
#             Artist          Album  Released
# 0  Michael Jackson       Thriller      1982
# 1            AC/DC  Back in Black      1980

# %%
z=df.iloc[0:2, 0:3]
z
# Out:
#             Artist          Album  Released
# 0  Michael Jackson       Thriller      1982
# 1            AC/DC  Back in Black      1980

# %%
z.loc[0,"Album"]
# Out:
# 'Thriller'

# %%
df.loc[0:2, 'Artist':'Genre']
# Out:
#             Artist                      Album  Released   Length  \
# 0  Michael Jackson                   Thriller      1982  0:42:19
# 1            AC/DC              Back in Black      1980  0:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  0:42:49
#
#               Genre
# 0    pop, rock, R&B
# 1         hard rock
# 2  progressive rock

# %% [markdown]
# # QUIZ DATAFRAME PANDAS

# %% [markdown]
# #Use a variable q to store the column Rating as a dataframe

# %%
q = df[['Rating']]
q
# Out:
#    Rating
# 0    10.0
# 1     9.5
# 2     9.0
# 3     8.5
# 4     8.0
# 5     7.5
# 6     7.0
# 7     6.5

# %% [markdown]
# #Assign the variable q to the dataframe that is made up of the column Released and Artist:

# %%
q = df[['Released', 'Artist']]
q
# Out:
#    Released           Artist
# 0      1982  Michael Jackson
# 1      1980            AC/DC
# 2      1973       Pink Floyd
# 3      1992  Whitney Houston
# 4      1977        Meat Loaf
# 5      1976           Eagles
# 6      1977         Bee Gees
# 7      1977    Fleetwood Mac

# %% [markdown]
# #Access the 2nd row and the 3rd column of df:

# %%
df.iloc[1, 2]
# Out:
# 1980

# %% [markdown]
# #Crea un nuevo index en un nuevo dataframe llamado "df_new" en vez de que sea de 0-7 que sea de a hasta h y muestra algunos elementos

# %%
new_index=['a','b','c','d','e','f','g','h']
df_new=df
df_new.index=new_index
df_new.loc['a', 'Artist']
df_new.loc['a':'h', 'Artist']
# Out:
# a    Michael Jackson
# b              AC/DC
# c         Pink Floyd
# d    Whitney Houston
# e          Meat Loaf
# f             Eagles
# g           Bee Gees
# h      Fleetwood Mac
# Name: Artist, dtype: object

# %% [markdown]
# # Progreso
#
# >![image.png](attachment:image.png)
